# %% [markdown]
# # This scipt is to push our code to Github

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/My Drive/DL_projects/speech_separation
# Out:
# /content/drive/My Drive/DL_projects/speech_separation

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/DL_projects/speech_separation/.git/

# %%
# Create Git Repo
# !git remote add origin https://AnnaGr-Git:Pwfgit25021998?!@github.com/AnnaGr-Git/speech_separation.git
# Add as a remote repo
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://AnnaGr-Git:Pwfgit25021998?!@github.com/AnnaGr-Git/speech_separation.git (fetch)
# origin	https://AnnaGr-Git:Pwfgit25021998?!@github.com/AnnaGr-Git/speech_separation.git (push)

# %%
# Tell git who we are
# !git config --global user.email 'anna.grillenberger@gmail.com'
# !git config --global user.name 'AnnaGr-Git'

# %%
# Create First Commit
# !git add .
# !git commit -m 'First commit'
# Out:
# [master d8b0552] First commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Kopie von git.ipynb

# %%
# Push code to master
# !git push origin master
# Out:
# fatal: unable to access 'https://AnnaGr-Git:Pwfgit25021998?!@github.com/AnnaGr-Git/speech_separation.git/': Port number ended with 'P'
